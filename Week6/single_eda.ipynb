# %%
import pandas as pd

# %%
sample1 = pd.read_csv('data2/rerere.csv')
sample2 = pd.read_csv('data2/rerere2.csv')

# %%
sample1.info()
sample2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482274 entries, 0 to 482273
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   자료생성년월  482274 non-null  int64
#  1   사업장명    482274 non-null  object
#  2   도로명주소   482274 non-null  object
#  3   업종코드명   471980 non-null  object
#  4   가입자수    482274 non-null  int64
#  5   고지금액    482274 non-null  int64
#  6   신규      482274 non-null  int64
#  7   상실      482274 non-null  int64
#  8   인당고지금액  482274 non-null  float64
#  9   평균월급    482274 non-null  float64
#  10  평균연봉    482274 non-null  float64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 40.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477371 entries, 0 to 477370
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   자료생성년월  477371 non-null  int64
#  1   사업장명    477371 non-null  object
#  2   도로명주소   477371 non-null  object
# ...

# %%
sample1.head(10)
# Out:
#    자료생성년월          사업장명               도로명주소                          업종코드명  \
# 0  201912       우성기전(주)    경기도 광주시 도척면 도척윗로                  동력식 수지 공구 제조업
# 1  201912  서능공원묘지운영회(재)                                 화장터 운영 묘지 분양 및 관리업
# 2  201912       노들새마을금고       서울특별시 동작구 만양로                           신용조합
# 3  201912       유창성업(주)       인천광역시 서구 갑문2로  그 외 기타 분류 안된 사업 지원 서비스업(기타임가공
# 4  201912       희성전자(주)   서울특별시 용산구 독서당로14길            비주거용 건물 임대업(점포 자기땅)
# 5  201912       동성교역(주)   서울특별시 강남구 테헤란로87길                     화학섬유직물 직조업
# 6  201912     (주)태평양그랜드         경기도 파주시 직지길                        스크린 인쇄업
# 7  201912       SK건설(주)     서울특별시 종로구 인사동7길                  기타 토목 시설물 건설업
# 8  201912       (주)태영건설   경기도 고양시 일산동구 정발산로                        아파트 건설업
# 9  201912       정하건설(주)  전라북도 전주시 덕진구 송천중앙로                 미장 타일 및 방수 공사업
#
#    가입자수        고지금액  신규  상실         인당고지금액          평균월급          평균연봉
# 0     6     1029020   0   0  171503.333333  1.905593e+06  2.286711e+07
# ...

# %%
sample1[(sample1['가입자수'] * 0.9 < sample1['상실']) & (sample1['평균연봉'] > 40000000)]
# Out:
#         자료생성년월                                            사업장명  \
# 397     201912                                         신촌상가(주)
# 660     201912                                         강동용역(주)
# 661     201912                                         남원산업(주)
# 1209    201912                                  헤라우스오리엔탈하이텍(주)
# 5500    201912                                       삼광가스테크(주)
# ...        ...                                             ...
# 482109  201912  삼정건설주식회사/일용/동인천중학교 다목적강당 및 급식소 증축공사 중 철근콘크리트공사
# 482139  201912              선진산업설비(주)/상용/00부대 간부숙소 기계공사(재-6-2)
# 482219  201912         유담종합건설(주)-(일용)삽교천삽교지구하천환경정비사업중조경시설물(5차)
# 482263  201912     갑을통신（주）/일용/2019년 언양울성남 7월 태풍 다나스 피해 복구 선로공사
# 482268  201912                         은산건업(주)/일용/고덕자이(서울)AL공사
#
#                        도로명주소                 업종코드명  가입자수      고지금액  신규  상실  \
# 397            서울특별시 마포구 신촌로   비주거용 건물 임대업(점포 자기땅)     3   1312200   0   3
# ...

# %%
sample1[(sample1['가입자수'] * 0.8 < sample1['상실']) & (sample1['가입자수'] * 0.9 > sample1['상실'])]
# Out:
#         자료생성년월                                               사업장명  \
# 737     201912                                            중앙양행(주)
# 2855    201912                                     생고뱅코리아홀딩스 주식회사
# 3541    201912                                     (주)케이디알한국기업서비스
# 3627    201912                                           선진프린팅(주)
# 4695    201912                                            한독광학(주)
# ...        ...                                                ...
# 478287  201912                (주)청수엔지니어링-(일용)천지선학원 신축공사 중 소방설비 공사
# 478771  201912  디에이치아이(주）/일용/보령LNGTerminalProject2-2단계205탱크및보온...
# 479469  201912                                           유한회사삼익지우
# 479879  201912                                     수원시팔달구청(생활안전과)
# 481248  201912            주식회사천우에스엔씨-(일용)더 메이 관광호텔 신축공사(건축)중 철골공사
#
#                      도로명주소                업종코드명  가입자수      고지금액  신규   상실  \
# 737       경기도 부천시 길주로412번길               모자 제조업     6   1211640   0    5
# ...

# %%
# Out:
#          index  자료생성년월                                               사업장명  \
# 0            0  201912                                            우성기전(주)
# 1            1  201912                                       서능공원묘지운영회(재)
# 2            2  201912                                            노들새마을금고
# 3            3  201912                                            유창성업(주)
# 4            4  201912                                            희성전자(주)
# ...        ...     ...                                                ...
# 482269  482269  201912         (주)성진전설/일용/포항시 남구 지곡동966-2 단독주택신축공사 중 전기공사
# 482270  482270  201912          대호전기주식회사/일용/계림 I PARK SK VIEW 중 옥외 임시동력공사
# 482271  482271  201912  （주）보림프러스/(일용)2015년 서수원 수인선 2-1공구 복선전철 원인자 지장이전...
# 482272  482272  201912                               (유)동명건설/일용/탑무인텔 증축공사
# 482273  482273  201912                 부경엔지니어링(주)-(일용)4차AMI 통신망 구축공사(1권역)
#
#                        도로명주소                          업종코드명  가입자수       고지금액  \
# ...
